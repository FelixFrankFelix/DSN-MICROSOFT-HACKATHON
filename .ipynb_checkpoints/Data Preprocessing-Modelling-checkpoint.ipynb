# %% [markdown]
# #### Import Neccesa

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import warnings

# Ignore all warnings
warnings.filterwarnings("ignore")
# Out:
# /kaggle/input/nigerian-housing-data-wgatap-real-estate-limited/Housing_dataset_test.csv
# /kaggle/input/nigerian-housing-data-wgatap-real-estate-limited/Housing_dataset_train.csv

# %%
test = pd.read_csv('/kaggle/input/nigerian-housing-data-wgatap-real-estate-limited/Housing_dataset_test.csv')
train = pd.read_csv('/kaggle/input/nigerian-housing-data-wgatap-real-estate-limited/Housing_dataset_train.csv')
train

# %%
train['ind'] = 1
test['ind'] = 0

# Concatenate train and test DataFrames
combined_df = pd.concat([train, test])

# Output the combined DataFrame
combined_df
# Out:
#          ID      loc                 title  bedroom  bathroom  parking_space  \
# 0      3583  Katsina  Semi-detached duplex      2.0       2.0            1.0
# 1      2748     Ondo             Apartment      NaN       2.0            4.0
# 2      9261    Ekiti                   NaN      7.0       5.0            NaN
# 3      2224  Anambra       Detached duplex      5.0       2.0            4.0
# 4     10300     Kogi        Terrace duplex      NaN       5.0            6.0
# ...     ...      ...                   ...      ...       ...            ...
# 5995   1594    Ekiti                  Flat      4.0       5.0            2.0
# 5996   2416  Adamawa        Terrace duplex      5.0       7.0            1.0
# 5997  10195      Oyo             Townhouse      4.0       1.0            4.0
# 5998   9455   Bauchi                  Flat      3.0       7.0            5.0
# 5999  11736   Sokoto               Mansion      6.0       1.0            6.0
#
#             price  ind
# 0     1149999.565    1
# 1     1672416.689    1
# 2     3364799.814    1
# 3     2410306.756    1
# 4     2600700.898    1
# ...           ...  ...
# 5995          NaN    0
# 5996          NaN    0
# 5997          NaN    0
# 5998          NaN    0
# 5999          NaN    0
#
# [20000 rows x 8 columns]

# %%
combined_df.dropna(subset=['loc','title'],inplace=True)
combined_df
# Out:
#          ID      loc                 title  bedroom  bathroom  parking_space  \
# 0      3583  Katsina  Semi-detached duplex      2.0       2.0            1.0
# 1      2748     Ondo             Apartment      NaN       2.0            4.0
# 3      2224  Anambra       Detached duplex      5.0       2.0            4.0
# 4     10300     Kogi        Terrace duplex      NaN       5.0            6.0
# 5      1733    Borno               Mansion      NaN       1.0            3.0
# ...     ...      ...                   ...      ...       ...            ...
# 5995   1594    Ekiti                  Flat      4.0       5.0            2.0
# 5996   2416  Adamawa        Terrace duplex      5.0       7.0            1.0
# 5997  10195      Oyo             Townhouse      4.0       1.0            4.0
# 5998   9455   Bauchi                  Flat      3.0       7.0            5.0
# 5999  11736   Sokoto               Mansion      6.0       1.0            6.0
#
#             price  ind
# 0     1149999.565    1
# 1     1672416.689    1
# 3     2410306.756    1
# 4     2600700.898    1
# 5     1341750.867    1
# ...           ...  ...
# 5995          NaN    0
# 5996          NaN    0
# 5997          NaN    0
# 5998          NaN    0
# 5999          NaN    0
#
# [16531 rows x 8 columns]

# %%
median_bedroom = combined_df['bedroom'].median()
combined_df['bedroom'].fillna(median_bedroom, inplace=True)

# %%
median_bathroom = combined_df['bathroom'].median()
combined_df['bathroom'].fillna(median_bathroom, inplace=True)

# %%
median_parking_space = combined_df['parking_space'].median()
combined_df['parking_space'].fillna(median_parking_space, inplace=True)

# %%
combined_df.isna().sum()
# Out:
# ID                  0
# loc                 0
# title               0
# bedroom             0
# bathroom            0
# parking_space       0
# price            6000
# ind                 0
# dtype: int64

# %%
combined_df['title_loc_combined'] = combined_df['title']+combined_df['loc']
combined_df
# Out:
#          ID      loc                 title  bedroom  bathroom  parking_space  \
# 0      3583  Katsina  Semi-detached duplex      2.0       2.0            1.0
# 1      2748     Ondo             Apartment      4.0       2.0            4.0
# 3      2224  Anambra       Detached duplex      5.0       2.0            4.0
# 4     10300     Kogi        Terrace duplex      4.0       5.0            6.0
# 5      1733    Borno               Mansion      4.0       1.0            3.0
# ...     ...      ...                   ...      ...       ...            ...
# 5995   1594    Ekiti                  Flat      4.0       5.0            2.0
# 5996   2416  Adamawa        Terrace duplex      5.0       7.0            1.0
# 5997  10195      Oyo             Townhouse      4.0       1.0            4.0
# 5998   9455   Bauchi                  Flat      3.0       7.0            5.0
# 5999  11736   Sokoto               Mansion      6.0       1.0            6.0
#
#             price  ind           title_loc_combined
# 0     1149999.565    1  Semi-detached duplexKatsina
# 1     1672416.689    1                ApartmentOndo
# 3     2410306.756    1       Detached duplexAnambra
# 4     2600700.898    1           Terrace duplexKogi
# 5     1341750.867    1                 MansionBorno
# ...           ...  ...                          ...
# 5995          NaN    0                    FlatEkiti
# 5996          NaN    0        Terrace duplexAdamawa
# 5997          NaN    0                 TownhouseOyo
# 5998          NaN    0                   FlatBauchi
# 5999          NaN    0                MansionSokoto
#
# [16531 rows x 9 columns]

# %%
combined_df['ratio_bed_bath'] = combined_df['bedroom']/combined_df['bathroom']
combined_df['sum_bed_bath_park'] = combined_df['bedroom']+combined_df['bathroom']+combined_df['parking_space']
#combined_df['ratio_bed'] = combined_df['bedroom']/combined_df['sum_bed_bath_park']
#combined_df['ratio_bath'] = combined_df['bathroom']/combined_df['sum_bed_bath_park']
#combined_df['ratio_park'] = combined_df['parking_space']/combined_df['sum_bed_bath_park']

#combined_df['conv'] = combined_df['ratio_bed_bath']*combined_df['sum_bed_bath_park']

# %%
population_density = {
    'Abia': 840,
    'Adamawa': 122.7,
    'Akwa Ibom': 726.0,
    'Anambra': 1264,
    'Bauchi': 273.9,
    'Bayelsa': 270.2,
    'Benue': 145.1,
    'Borno': 84.70,
    'Cross River': 209.6,
    'Delta': 331.8,
    'Ebonyi': 499.8,
    'Edo': 244.2,
    'Ekiti': 621.3,
    'Enugu': 1300,
    'Gombe': 238.0,
    'Imo': 1063,
    'Jigawa': 319.9,
    'Kaduna': 200.4,
    'Kano': 764.3,
    'Katsina': 427.8,
    'Kebbi': 149.6,
    'Kogi': 154.1,
    'Kwara': 106.2,
    'Lagos': 3791,
    'Nasarawa': 109.9,
    'Niger': 95.60,
    'Ogun': 382.8,
    'Ondo': 353.3,
    'Osun': 520.6,
    'Oyo': 288.5,
    'Plateau': 181.3,
    'Rivers': 773.3,
    'Sokoto': 205.9,
    'Taraba': 61.40,
    'Yobe': 79.77,
    'Zamfara': 170.2
}


# Get the population densities as a list
population_densities = list(population_density.values())

# Calculate percentiles
percentiles = [0, 20, 40, 60, 100]
population_percentiles = [np.percentile(population_densities, p) for p in percentiles]

# Categorize states based on percentiles
class_1 = [state for state, density in population_density.items() if density > population_percentiles[4]]
class_2 = [state for state, density in population_density.items() if density > population_percentiles[3] and density <= population_percentiles[4]]
class_3 = [state for state, density in population_density.items() if density > population_percentiles[2] and density <= population_percentiles[3]]
class_4 = [state for state, density in population_density.items() if density > population_percentiles[1] and density <= population_percentiles[2]]
class_5 = [state for state, density in population_density.items() if density <= population_percentiles[1]]

# Print the states in each population density class
print('Class 1:', class_1)
print('Class 2:', class_2)
print('Class 3:', class_3)
print('Class 4:', class_4)
print('Class 5:', class_5)

# %%
combined_df['population_density_level'] = combined_df['loc'].apply(lambda x: 5 if x in class_1
                                                     else 4 if x in class_2
                                                     else 3 if x in class_3
                                                     else 2 if x in class_4
                                                     else 1 if x in class_5
                                                     else 0)

# %%
population_level_1 = ['Anambra', 'Enugu', 'Imo', 'Lagos']
population_level_2 = ['Abia', 'Kano', 'Rivers']
population_level_3 = ['Akwa Ibom', 'Ebonyi', 'Ekiti', 'Osun']
population_level_4 = ['Katsina', 'Ogun', 'Ondo']
population_level_5 = ['Bauchi', 'Delta', 'Jigawa', 'Oyo']
population_level_6 = ['Bayelsa', 'Edo', 'Gombe']
population_level_7 = ['Cross River', 'Kaduna', 'Plateau', 'Sokoto']
population_level_8 = ['Kebbi', 'Kogi', 'Zamfara']
population_level_9 = ['Adamawa', 'Benue', 'Kwara', 'Nasarawa']
population_level_10 = ['Borno', 'Niger', 'Taraba', 'Yobe']

combined_df['population_density_level'] = combined_df['loc'].apply(lambda x: 10 if x in population_level_1
                                                                    else 9 if x in population_level_2
                                                                    else 8 if x in population_level_3
                                                                    else 7 if x in population_level_4
                                                                    else 6 if x in population_level_5
                                                                    else 5 if x in population_level_6
                                                                    else 4 if x in population_level_7
                                                                    else 3 if x in population_level_8
                                                                    else 2 if x in population_level_9
                                                                    else 1 if x in population_level_10
                                                                    else 0)


  
combined_df
# Out:
#          ID      loc                 title  bedroom  bathroom  parking_space  \
# 0      3583  Katsina  Semi-detached duplex      2.0       2.0            1.0
# 1      2748     Ondo             Apartment      4.0       2.0            4.0
# 3      2224  Anambra       Detached duplex      5.0       2.0            4.0
# 4     10300     Kogi        Terrace duplex      4.0       5.0            6.0
# 5      1733    Borno               Mansion      4.0       1.0            3.0
# ...     ...      ...                   ...      ...       ...            ...
# 5995   1594    Ekiti                  Flat      4.0       5.0            2.0
# 5996   2416  Adamawa        Terrace duplex      5.0       7.0            1.0
# 5997  10195      Oyo             Townhouse      4.0       1.0            4.0
# 5998   9455   Bauchi                  Flat      3.0       7.0            5.0
# 5999  11736   Sokoto               Mansion      6.0       1.0            6.0
#
#             price  ind           title_loc_combined  ratio_bed_bath  \
# 0     1149999.565    1  Semi-detached duplexKatsina        1.000000
# 1     1672416.689    1                ApartmentOndo        2.000000
# 3     2410306.756    1       Detached duplexAnambra        2.500000
# 4     2600700.898    1           Terrace duplexKogi        0.800000
# 5     1341750.867    1                 MansionBorno        4.000000
# ...           ...  ...                          ...             ...
# 5995          NaN    0                    FlatEkiti        0.800000
# 5996          NaN    0        Terrace duplexAdamawa        0.714286
# 5997          NaN    0                 TownhouseOyo        4.000000
# 5998          NaN    0                   FlatBauchi        0.428571
# 5999          NaN    0                MansionSokoto        6.000000
#
#       sum_bed_bath_park  population_density_level
# 0                   5.0                         7
# 1                  10.0                         7
# 3                  11.0                        10
# 4                  15.0                         3
# 5                   8.0                         1
# ...                 ...                       ...
# 5995               11.0                         8
# 5996               13.0                         2
# 5997                9.0                         6
# 5998               15.0                         6
# 5999               13.0                         4
#
# [16531 rows x 12 columns]

# %%
import category_encoders as ce

# Assuming you have the combined_df DataFrame with 'loc' and 'price' columns

# Create a new DataFrame to store the encoded values
encoded_df = combined_df.copy()

# Define the encoder instance
encoder = ce.TargetEncoder(cols=['loc'])

# Fit the encoder on the 'loc' column and 'price' target variable
encoder.fit(encoded_df['loc'], encoded_df['price'])

# Transform the 'loc' column with the encoded values
encoded_df['loc_encoded'] = encoder.transform(encoded_df['loc'])

# Drop the original 'loc' column if you no longer need it
encoded_df.drop('loc', axis=1, inplace=True)

# Print the updated DataFrame with the encoded 'loc' column
encoded_df
# Out:
#          ID                 title  bedroom  bathroom  parking_space  \
# 0      3583  Semi-detached duplex      2.0       2.0            1.0
# 1      2748             Apartment      4.0       2.0            4.0
# 3      2224       Detached duplex      5.0       2.0            4.0
# 4     10300        Terrace duplex      4.0       5.0            6.0
# 5      1733               Mansion      4.0       1.0            3.0
# ...     ...                   ...      ...       ...            ...
# 5995   1594                  Flat      4.0       5.0            2.0
# 5996   2416        Terrace duplex      5.0       7.0            1.0
# 5997  10195             Townhouse      4.0       1.0            4.0
# 5998   9455                  Flat      3.0       7.0            5.0
# 5999  11736               Mansion      6.0       1.0            6.0
#
#             price  ind           title_loc_combined  ratio_bed_bath  \
# 0     1149999.565    1  Semi-detached duplexKatsina        1.000000
# 1     1672416.689    1                ApartmentOndo        2.000000
# 3     2410306.756    1       Detached duplexAnambra        2.500000
# 4     2600700.898    1           Terrace duplexKogi        0.800000
# 5     1341750.867    1                 MansionBorno        4.000000
# ...           ...  ...                          ...             ...
# 5995          NaN    0                    FlatEkiti        0.800000
# 5996          NaN    0        Terrace duplexAdamawa        0.714286
# 5997          NaN    0                 TownhouseOyo        4.000000
# 5998          NaN    0                   FlatBauchi        0.428571
# 5999          NaN    0                MansionSokoto        6.000000
#
#       sum_bed_bath_park  population_density_level   loc_encoded
# 0                   5.0                         7  1.951331e+06
# 1                  10.0                         7  2.252539e+06
# 3                  11.0                        10  2.364226e+06
# 4                  15.0                         3  1.761459e+06
# 5                   8.0                         1  1.713052e+06
# ...                 ...                       ...           ...
# 5995               11.0                         8  2.107909e+06
# 5996               13.0                         2  1.881336e+06
# 5997                9.0                         6  2.287374e+06
# 5998               15.0                         6  1.748597e+06
# 5999               13.0                         4  1.673768e+06
#
# [16531 rows x 12 columns]

# %%
import category_encoders as ce

# Assuming you have the combined_df DataFrame with 'loc' and 'price' columns

# Create a new DataFrame to store the encoded values

# Define the encoder instance
encoder = ce.TargetEncoder(cols=['title'])

# Fit the encoder on the 'loc' column and 'price' target variable
encoder.fit(encoded_df['title'], encoded_df['price'])

# Transform the 'loc' column with the encoded values
encoded_df['title_encoded'] = encoder.transform(encoded_df['title'])

# Drop the original 'loc' column if you no longer need it
encoded_df.drop('title', axis=1, inplace=True)

# Print the updated DataFrame with the encoded 'loc' column
encoded_df
# Out:
#          ID  bedroom  bathroom  parking_space        price  ind  \
# 0      3583      2.0       2.0            1.0  1149999.565    1
# 1      2748      4.0       2.0            4.0  1672416.689    1
# 3      2224      5.0       2.0            4.0  2410306.756    1
# 4     10300      4.0       5.0            6.0  2600700.898    1
# 5      1733      4.0       1.0            3.0  1341750.867    1
# ...     ...      ...       ...            ...          ...  ...
# 5995   1594      4.0       5.0            2.0          NaN    0
# 5996   2416      5.0       7.0            1.0          NaN    0
# 5997  10195      4.0       1.0            4.0          NaN    0
# 5998   9455      3.0       7.0            5.0          NaN    0
# 5999  11736      6.0       1.0            6.0          NaN    0
#
#                title_loc_combined  ratio_bed_bath  sum_bed_bath_park  \
# 0     Semi-detached duplexKatsina        1.000000                5.0
# 1                   ApartmentOndo        2.000000               10.0
# 3          Detached duplexAnambra        2.500000               11.0
# 4              Terrace duplexKogi        0.800000               15.0
# 5                    MansionBorno        4.000000                8.0
# ...                           ...             ...                ...
# 5995                    FlatEkiti        0.800000               11.0
# 5996        Terrace duplexAdamawa        0.714286               13.0
# 5997                 TownhouseOyo        4.000000                9.0
# 5998                   FlatBauchi        0.428571               15.0
# 5999                MansionSokoto        6.000000               13.0
#
#       population_density_level   loc_encoded  title_encoded
# 0                            7  1.951331e+06   1.908512e+06
# 1                            7  2.252539e+06   1.573772e+06
# 3                           10  2.364226e+06   2.208319e+06
# 4                            3  1.761459e+06   1.930154e+06
# 5                            1  1.713052e+06   3.712847e+06
# ...                        ...           ...            ...
# 5995                         8  2.107909e+06   1.727680e+06
# 5996                         2  1.881336e+06   1.930154e+06
# 5997                         6  2.287374e+06   2.044775e+06
# 5998                         6  1.748597e+06   1.727680e+06
# 5999                         4  1.673768e+06   3.712847e+06
#
# [16531 rows x 12 columns]

# %%
import category_encoders as ce

# Assuming you have the combined_df DataFrame with 'loc' and 'price' columns

# Create a new DataFrame to store the encoded values

# Define the encoder instance
encoder = ce.TargetEncoder(cols=['title_loc_combined'])

# Fit the encoder on the 'loc' column and 'price' target variable
encoder.fit(encoded_df['title_loc_combined'], encoded_df['price'])

# Transform the 'loc' column with the encoded values
encoded_df['title_loc_encoded'] = encoder.transform(encoded_df['title_loc_combined'])

# Drop the original 'loc' column if you no longer need it
encoded_df.drop('title_loc_combined', axis=1, inplace=True)

# Print the updated DataFrame with the encoded 'loc' column
encoded_df
# Out:
#          ID  bedroom  bathroom  parking_space        price  ind  \
# 0      3583      2.0       2.0            1.0  1149999.565    1
# 1      2748      4.0       2.0            4.0  1672416.689    1
# 3      2224      5.0       2.0            4.0  2410306.756    1
# 4     10300      4.0       5.0            6.0  2600700.898    1
# 5      1733      4.0       1.0            3.0  1341750.867    1
# ...     ...      ...       ...            ...          ...  ...
# 5995   1594      4.0       5.0            2.0          NaN    0
# 5996   2416      5.0       7.0            1.0          NaN    0
# 5997  10195      4.0       1.0            4.0          NaN    0
# 5998   9455      3.0       7.0            5.0          NaN    0
# 5999  11736      6.0       1.0            6.0          NaN    0
#
#       ratio_bed_bath  sum_bed_bath_park  population_density_level  \
# 0           1.000000                5.0                         7
# 1           2.000000               10.0                         7
# 3           2.500000               11.0                        10
# 4           0.800000               15.0                         3
# 5           4.000000                8.0                         1
# ...              ...                ...                       ...
# 5995        0.800000               11.0                         8
# 5996        0.714286               13.0                         2
# 5997        4.000000                9.0                         6
# 5998        0.428571               15.0                         6
# 5999        6.000000               13.0                         4
#
#        loc_encoded  title_encoded  title_loc_encoded
# 0     1.951331e+06   1.908512e+06       1.766286e+06
# 1     2.252539e+06   1.573772e+06       1.626202e+06
# 3     2.364226e+06   2.208319e+06       2.183431e+06
# 4     1.761459e+06   1.930154e+06       1.854822e+06
# 5     1.713052e+06   3.712847e+06       2.689337e+06
# ...            ...            ...                ...
# 5995  2.107909e+06   1.727680e+06       1.924422e+06
# 5996  1.881336e+06   1.930154e+06       1.788757e+06
# 5997  2.287374e+06   2.044775e+06       2.119640e+06
# 5998  1.748597e+06   1.727680e+06       1.754999e+06
# 5999  1.673768e+06   3.712847e+06       2.451596e+06
#
# [16531 rows x 12 columns]

# %%
combined_df = encoded_df

# %%
train = combined_df[combined_df.ind == 1]
test = combined_df[combined_df.ind == 0]

train.drop('ind',axis=1,inplace=True)
test.drop(['ind','price'],axis=1,inplace=True)
train
# Out:
#           ID  bedroom  bathroom  parking_space        price  ratio_bed_bath  \
# 0       3583      2.0       2.0            1.0  1149999.565        1.000000
# 1       2748      4.0       2.0            4.0  1672416.689        2.000000
# 3       2224      5.0       2.0            4.0  2410306.756        2.500000
# 4      10300      4.0       5.0            6.0  2600700.898        0.800000
# 5       1733      4.0       1.0            3.0  1341750.867        4.000000
# ...      ...      ...       ...            ...          ...             ...
# 13994  10477      8.0       1.0            6.0  2837199.086        8.000000
# 13995   6175      4.0       7.0            3.0  2367927.861        0.571429
# 13996   9704      4.0       7.0            5.0  2228516.471        0.571429
# 13997  11190      8.0       6.0            5.0  2406812.693        1.333333
# 13998   9256      4.0       6.0            1.0  3348918.718        0.666667
#
#        sum_bed_bath_park  population_density_level   loc_encoded  \
# 0                    5.0                         7  1.951331e+06
# 1                   10.0                         7  2.252539e+06
# 3                   11.0                        10  2.364226e+06
# 4                   15.0                         3  1.761459e+06
# 5                    8.0                         1  1.713052e+06
# ...                  ...                       ...           ...
# 13994               15.0                         1  1.853125e+06
# 13995               14.0                         5  2.304194e+06
# 13996               16.0                         4  1.868486e+06
# 13997               19.0                         4  1.926366e+06
# 13998               11.0                         6  2.749262e+06
#
#        title_encoded  title_loc_encoded
# 0       1.908512e+06       1.766286e+06
# 1       1.573772e+06       1.626202e+06
# 3       2.208319e+06       2.183431e+06
# 4       1.930154e+06       1.854822e+06
# 5       3.712847e+06       2.689337e+06
# ...              ...                ...
# 13994   2.208319e+06       1.967860e+06
# 13995   1.732655e+06       1.986381e+06
# 13996   1.573772e+06       1.543603e+06
# 13997   1.732655e+06       1.665966e+06
# 13998   1.727680e+06       2.010282e+06
#
# [10531 rows x 11 columns]

# %%
#X = train.drop(['geopolitical_zone'],axis=1)
X = train.drop(['ID','price'],axis=1)
y = train.price
X
# Out:
#        bedroom  bathroom  parking_space  ratio_bed_bath  sum_bed_bath_park  \
# 0          2.0       2.0            1.0        1.000000                5.0
# 1          4.0       2.0            4.0        2.000000               10.0
# 3          5.0       2.0            4.0        2.500000               11.0
# 4          4.0       5.0            6.0        0.800000               15.0
# 5          4.0       1.0            3.0        4.000000                8.0
# ...        ...       ...            ...             ...                ...
# 13994      8.0       1.0            6.0        8.000000               15.0
# 13995      4.0       7.0            3.0        0.571429               14.0
# 13996      4.0       7.0            5.0        0.571429               16.0
# 13997      8.0       6.0            5.0        1.333333               19.0
# 13998      4.0       6.0            1.0        0.666667               11.0
#
#        population_density_level   loc_encoded  title_encoded  \
# 0                             7  1.951331e+06   1.908512e+06
# 1                             7  2.252539e+06   1.573772e+06
# 3                            10  2.364226e+06   2.208319e+06
# 4                             3  1.761459e+06   1.930154e+06
# 5                             1  1.713052e+06   3.712847e+06
# ...                         ...           ...            ...
# 13994                         1  1.853125e+06   2.208319e+06
# 13995                         5  2.304194e+06   1.732655e+06
# 13996                         4  1.868486e+06   1.573772e+06
# 13997                         4  1.926366e+06   1.732655e+06
# 13998                         6  2.749262e+06   1.727680e+06
#
#        title_loc_encoded
# 0           1.766286e+06
# 1           1.626202e+06
# 3           2.183431e+06
# 4           1.854822e+06
# 5           2.689337e+06
# ...                  ...
# 13994       1.967860e+06
# 13995       1.986381e+06
# 13996       1.543603e+06
# 13997       1.665966e+06
# 13998       2.010282e+06
#
# [10531 rows x 9 columns]

# %%
from catboost import CatBoostRegressor
import numpy as np
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import cross_val_score, KFold

# Assuming you have the features in X and the target variable in y

# Define the CatBoost model
model = CatBoostRegressor(loss_function='RMSE', random_seed=42,silent=True)

# Define the cross-validation strategy
cv = KFold(n_splits=5, shuffle=True, random_state=42)

# Perform cross-validation and calculate RMSE
rmse_scores = np.sqrt(-cross_val_score(model, X, y, cv=cv, scoring='neg_mean_squared_error'))

# Train the model on the entire dataset
model.fit(X, y)

# Print the cross-validation RMSE scores
print('Cross-Validation RMSE:', rmse_scores)
print(rmse_scores.mean())
# Out:
# Cross-Validation RMSE: [433546.49898538 457136.25336585 391563.15625666 429707.23590519
#  400145.41662088]
# 422419.71222679236

# %%
import matplotlib.pyplot as plt
feature_importance = model.get_feature_importance()

# Get the names of the features
feature_names = X.columns

# Create a DataFrame to store the feature importance scores with corresponding feature names
feature_importance_df = pd.DataFrame({'Feature': feature_names, 'Importance': feature_importance})

# Sort the DataFrame by importance in descending order
feature_importance_df = feature_importance_df.sort_values(by='Importance', ascending=False)

# Plot the feature importance
plt.figure(figsize=(10, 6))
plt.bar(feature_importance_df['Feature'], feature_importance_df['Importance'])
plt.xticks(rotation=90)
plt.xlabel('Feature')
plt.ylabel('Importance')
plt.title('Feature Importance')
plt.show()

# %%
X_test = test.drop(['ID'], axis=1)

# Use the trained model to predict prices for the test dataset
y_pred = model.predict(X_test)

# Reshape the predicted values to be a 1-dimensional array
y_pred = y_pred.reshape(-1)

# Create a DataFrame with ID and predicted price columns
predictions_df = pd.DataFrame({'ID': test['ID'], 'price': y_pred})

# Display the predictions DataFrame
predictions_df
# Out:
#          ID         price
# 0       845  2.147685e+06
# 1      1924  1.072574e+06
# 2     10718  1.292110e+06
# 3     12076  8.476538e+06
# 4     12254  2.056299e+06
# ...     ...           ...
# 5995   1594  1.785994e+06
# 5996   2416  1.976942e+06
# 5997  10195  1.940039e+06
# 5998   9455  1.341961e+06
# 5999  11736  3.361382e+06
#
# [6000 rows x 2 columns]

# %%
predictions_df.to_csv('sub86.csv', index=False)
